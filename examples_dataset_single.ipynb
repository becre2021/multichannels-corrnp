# %%
import torch
import numpy as np

# %%
#from dataset_singletask_1d import prepare_mixed_1dtask,task_list

# %%
import matplotlib.pyplot as plt

# %%
#batch_trainset = torch.load('./syndata_singletask_v1/depTrue_extra_1.db')['train_set']
#batch_trainset = torch.load('./syndata_singletask_v1/depTrue_extra_-128.db')['train_set']
#batch_trainset = torch.load('./syndata_singletask_v1/depTrue_extra_-128.db')['valid_set']
#batch_trainset = torch.load('./regression_task_single/syndata_singletask_v1/depTrue_extra_-128.db')['valid_set']


#batch_trainset = torch.load('./syndata_singletask_v2/depTrue_extra_-128.db')['valid_set']

batch_smallset = torch.load('./syndata_singletask_v1_test/depTrue_extra_nvaltask128.db')

# %%
# print('xc.shape,yc.shape,xt.shape,yt.shape,xf.shape,yf.shape')
# print(xc.shape,yc.shape,xt.shape,yt.shape,xf.shape,yf.shape)

intrain = True

# %%
figsiz_=(12,2.5)
#for j in range(2):
epochidx_list = [10,20]
#batchidx_list = [0,4,8]
batchidx_list = [0,8]

for ith_epochidx in epochidx_list:
    for ith_task in batch_smallset:
        print('-'*100)
        print('intrain {}: \t task: {} with epoch {}'.format(intrain,ith_task,ith_epochidx))
        print('-'*100)
        if intrain:
            xc,yc,xt,yt,xf,yf = batch_smallset[ith_task]['train_set'][ith_epochidx]
        else:
            xc,yc,xt,yt,xf,yf = batch_smallset[ith_task]['valid_set'][ith_epochidx]        
            
        print('xc.size(),yc.size(),xt.size(),yt.size()')
        print(xc.size(),yc.size(),xt.size(),yt.size())
        
        for j in batchidx_list:
            plt.figure(figsize=figsiz_)
            plt.plot(xf[j,:,0].cpu().data.numpy(),yf[j,:,0].cpu().data.numpy(),linewidth=2.5,color='k',alpha=0.8,label='true')
            plt.scatter(xc[j,:,0].cpu().data.numpy(),yc[j,:,0].cpu().data.numpy(),s=50,color='r',label='context')
            plt.scatter(xt[j,:,0].cpu().data.numpy(),yt[j,:,0].cpu().data.numpy(),s=50,color='b',label='target')
            plt.legend(fontsize=15)
            plt.show()

        print('\n'*1)

    print('\n'*3)
# Out:
# ----------------------------------------------------------------------------------------------------
# intrain True: 	 task: rbf with epoch 10
# ----------------------------------------------------------------------------------------------------
# xc.size(),yc.size(),xt.size(),yt.size()
# torch.Size([16, 9, 1]) torch.Size([16, 9, 1]) torch.Size([16, 30, 1]) torch.Size([16, 30, 1])
# ----------------------------------------------------------------------------------------------------
# intrain True: 	 task: matern with epoch 10
# ----------------------------------------------------------------------------------------------------
# xc.size(),yc.size(),xt.size(),yt.size()
# torch.Size([16, 11, 1]) torch.Size([16, 11, 1]) torch.Size([16, 25, 1]) torch.Size([16, 25, 1])
# ----------------------------------------------------------------------------------------------------
# intrain True: 	 task: weaklyperiodic with epoch 10
# ----------------------------------------------------------------------------------------------------
# xc.size(),yc.size(),xt.size(),yt.size()
# torch.Size([16, 17, 1]) torch.Size([16, 17, 1]) torch.Size([16, 39, 1]) torch.Size([16, 39, 1])
# ----------------------------------------------------------------------------------------------------
# intrain True: 	 task: sawtooth with epoch 10
# ----------------------------------------------------------------------------------------------------
# xc.size(),yc.size(),xt.size(),yt.size()
# torch.Size([16, 17, 1]) torch.Size([16, 17, 1]) torch.Size([16, 35, 1]) torch.Size([16, 35, 1])
# ----------------------------------------------------------------------------------------------------
# intrain True: 	 task: rbf with epoch 20
# ----------------------------------------------------------------------------------------------------
# xc.size(),yc.size(),xt.size(),yt.size()
# torch.Size([16, 16, 1]) torch.Size([16, 16, 1]) torch.Size([16, 42, 1]) torch.Size([16, 42, 1])
# ----------------------------------------------------------------------------------------------------
# intrain True: 	 task: matern with epoch 20
# ----------------------------------------------------------------------------------------------------
# xc.size(),yc.size(),xt.size(),yt.size()
# torch.Size([16, 23, 1]) torch.Size([16, 23, 1]) torch.Size([16, 36, 1]) torch.Size([16, 36, 1])
# ----------------------------------------------------------------------------------------------------
# intrain True: 	 task: weaklyperiodic with epoch 20
# ----------------------------------------------------------------------------------------------------
# xc.size(),yc.size(),xt.size(),yt.size()
# torch.Size([16, 6, 1]) torch.Size([16, 6, 1]) torch.Size([16, 47, 1]) torch.Size([16, 47, 1])
# ----------------------------------------------------------------------------------------------------
# intrain True: 	 task: sawtooth with epoch 20
# ----------------------------------------------------------------------------------------------------
# xc.size(),yc.size(),xt.size(),yt.size()
# torch.Size([16, 23, 1]) torch.Size([16, 23, 1]) torch.Size([16, 23, 1]) torch.Size([16, 23, 1])
