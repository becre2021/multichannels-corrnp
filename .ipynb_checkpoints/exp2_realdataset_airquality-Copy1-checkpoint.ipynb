# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
#import stheno.torch as stheno

import convcnp.data
from convcnp.experiment import report_loss, RunningAverage
from convcnp.utils import gaussian_logpdf, init_sequential_weights, to_multiple
from convcnp.architectures import SimpleConv, UNet

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


def to_numpy(x):
    """Convert a PyTorch tensor to NumPy."""
    return x.squeeze().detach().cpu().numpy()

# %%
import mogptk
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## dataset = AirQualityUCI.csv

# %%
from collections import OrderedDict



df = pd.read_csv('data/AirQualityUCI.csv', delimiter=';') #03/10

# Replace missing values with NaN
df.replace(-200.0, np.nan, inplace=True)

df['Date'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], format='%d/%m/%Y %H.%M.%S')
# Define an initial date to compare all other to it
ini_date = pd.Timestamp('2004-03-10 00:00:00.0')
# Get elapsed hours
df['Time'] = (df['Date'] - ini_date) / pd.Timedelta(hours=1)
#df2 = df[df['Date'] < pd.Timestamp('2004-03-18 00:00:00.0')]
df2 = df[df['Date'] < pd.Timestamp('2004-03-20 00:00:00.0')]

cols = ['CO(GT)', 'NMHC(GT)', 'C6H6(GT)', 'NOx(GT)', 'NO2(GT)']
dataset = mogptk.LoadDataFrame(df2, x_col='Time', y_col=cols)
num_channels = 5

#-----------
#descpriont
#-----------

# 'CO(GT)', 'NMHC(GT)', 'C6H6(GT)', 'NOx(GT)', 'NO2(GT)'
# dataset_dict[0] = 
# dataset_dict[1] = 
# dataset_dict[2] =
# dataset_dict[3] = 
# dataset_dict[4] = 

time_scale = 24
normalize=True
dataset_dict = OrderedDict()
X,Y = [],[]
for ith,ith_col in enumerate(cols):
    #dataset_dict[ith_col] = {}
    dataset_dict[ith] = {}
    
    x,y = dataset[ith_col].get_data()    
    #print(x)
    #dataset_dict[ith_col]['x'] = np.array(x,np.float32).squeeze()
    #dataset_dict[ith_col]['y'] = np.array(y,np.float32).squeeze()
    dataset_dict[ith]['x'] = np.array(x,np.float32).squeeze()
    dataset_dict[ith]['y'] = np.array(y,np.float32).squeeze()

    if normalize == True:
        #dataset_dict[ith_col]['y'] = (dataset_dict[ith_col]['y'] - dataset_dict[ith_col]['y'].mean())/dataset_dict[ith_col]['y'].std()
        dataset_dict[ith]['y'] = (dataset_dict[ith]['y'] - dataset_dict[ith]['y'].mean())/dataset_dict[ith]['y'].std()
        dataset_dict[ith]['x'] /= time_scale

# %% [markdown]
# ## preparation dataset: bramblemet
# ### checked working but exploration quite not fitted well

# %%
# from collections import OrderedDict

# start_date = '2020-06-02'
# #end_date = '2020-06-08'
# end_date = '2020-06-07'

# print('Loading Bramble')
# bramblemet = pd.read_csv('data/bramblemet/bramblemet.csv.gz', compression='gzip', low_memory=False)
# bramblemet['Date'] = pd.to_datetime(bramblemet['Date'] + ' ' + bramblemet['Time'], format='%d/%m/%Y %H:%M')
# bramblemet = bramblemet.drop(columns=['Time'])
# bramblemet = bramblemet.loc[(bramblemet['Date'] >= start_date) & (bramblemet['Date'] < end_date)]

# print('Loading Camber')
# cambermet = pd.read_csv('data/bramblemet/cambermet.csv.gz', compression='gzip', low_memory=False)
# cambermet['Date'] = pd.to_datetime(cambermet['Date'] + ' ' + cambermet['Time'], format='%d/%m/%Y %H:%M')
# cambermet = cambermet.drop(columns=['Time'])
# cambermet = cambermet.loc[(cambermet['Date'] >= start_date) & (cambermet['Date'] < end_date)]

# print('Loading Chi')
# chimet = pd.read_csv('data/bramblemet/chimet.csv.gz', compression='gzip', low_memory=False)
# chimet['Date'] = pd.to_datetime(chimet['Date'] + ' ' + chimet['Time'], format='%d/%m/%Y %H:%M')
# chimet = chimet.drop(columns=['Time'])
# chimet = chimet.loc[(chimet['Date'] >= start_date) & (chimet['Date'] < end_date)]

# print('Loading Soton')
# sotonmet = pd.read_csv('data/bramblemet/sotonmet.csv.gz', compression='gzip', low_memory=False)
# sotonmet['Date'] = pd.to_datetime(sotonmet['Date'] + ' ' + sotonmet['Time'], format='%d/%m/%Y %H:%M')
# sotonmet = sotonmet.drop(columns=['Time'])
# sotonmet = sotonmet.loc[(sotonmet['Date'] >= start_date) & (sotonmet['Date'] < end_date)]



# normalize=True
# dataset_dict = OrderedDict()
# # dataset_dict['bramblemet'] = bramblemet
# # dataset_dict['cambermet'] = cambermet
# # dataset_dict['chimet'] = chimet
# # dataset_dict['sotonmet'] = sotonmet
# dataset_dict[0] = bramblemet
# dataset_dict[1] = cambermet
# dataset_dict[2] = chimet
# dataset_dict[3] = sotonmet

# num_channels = 4
# default_round = 100000000000

# time_scale = 60*24 #5minute per obesration
# for ith_dict in dataset_dict:
#     x = dataset_dict[ith_dict]['Date'].to_numpy().astype('int')/default_round
#     y = dataset_dict[ith_dict]['DEPTH'].to_numpy(dtype=np.float32)    
#     #dataset_dict[ith_dict] = 
#     x,y = np.asarray(x,dtype=np.float32),np.asarray(y,dtype=np.float32)
#     dataset_dict[ith_dict] = {}
#     dataset_dict[ith_dict]['x'] = x
#     dataset_dict[ith_dict]['y'] = y
    
    
#     if normalize == True:
#         dataset_dict[ith_dict]['x'] -= dataset_dict[ith_dict]['x'][0]
#         dataset_dict[ith_dict]['x'] /= time_scale
#         dataset_dict[ith_dict]['y'] = (dataset_dict[ith_dict]['y'] - dataset_dict[ith_dict]['y'].mean())/dataset_dict[ith_dict]['y'].std()

        
        
        
        
# print('')
# for ith_key in dataset_dict:
#     print(ith_key,len(dataset_dict[ith_key]['x']))

# %%
def get_index(dataset_dict,test_type = 'inter',test_len=24):
    
    time_dict_index = {}    
    if test_type == 'inter':
        for ith_channel in dataset_dict:
            #print(dataset_dict[ith_channel]['x'])
            full_len = len(dataset_dict[ith_channel]['x'])
            
            start_index = np.random.choice(full_len-test_len,1)[0]

            full_idx = np.arange(full_len)
            target_idx = np.arange(start_index,start_index+test_len)
            context_idx = np.setdiff1d(full_idx,target_idx)
            time_dict_index[ith_channel] = {'context_idx':context_idx,'target_idx':target_idx}
    
    elif test_type == 'extra':
        for ith_channel in dataset_dict:  
            full_len = len(dataset_dict[ith_channel]['x'])            
            full_idx = np.arange(full_len)
            target_idx = full_idx[-test_len:]
            context_idx = full_idx[:-test_len]
            #print(full_index)
            #print(target_idx,context_idx)
            #print('')
            time_dict_index[ith_channel] = {'context_idx':context_idx,'target_idx':target_idx}        
    else:
        pass
    
    return time_dict_index
    
    
#

# %%
#dataset_dict

#def prepare_batch(dataset_dict, time_dict_index

def prepare_batch(dataset_dict, time_dict_index , nbatch = 32,batch_npoints=(64,64), intrain = True):
    context_x,context_y = [],[]
    target_x,target_y = [],[]
    full_x,full_y = [],[]
    
    #n_points = len(x)
    #time_dict_index = get_index(dataset_dict,test_option = test_option,test_len=test_len)
    
    for _ in range(nbatch):

        i_context_x,i_context_y = [],[]
        i_target_x,i_target_y = [],[]
        i_full_x,i_full_y = [],[]
        for ith_channel in time_dict_index:
            if intrain :
                sampled_c_idx = np.random.choice(time_dict_index[ith_channel]['context_idx'],min(batch_npoints[0],len(time_dict_index[ith_channel]['context_idx'])))
                sampled_t_idx = np.random.choice(time_dict_index[ith_channel]['context_idx'],min(batch_npoints[0],len(time_dict_index[ith_channel]['context_idx'])))
                sampled_c_idx.sort() 
                sampled_t_idx.sort() 
                ith_context_x,ith_context_y = dataset_dict[ith_channel]['x'][sampled_c_idx],dataset_dict[ith_channel]['y'][sampled_c_idx]
                ith_target_x,ith_target_y = dataset_dict[ith_channel]['x'][sampled_t_idx],dataset_dict[ith_channel]['y'][sampled_t_idx]        
                
                
                

            else:                
                sampled_c_idx = np.random.choice(time_dict_index[ith_channel]['context_idx'],min(batch_npoints[0],len(time_dict_index[ith_channel]['context_idx'])))
                sampled_t_idx = np.random.choice(time_dict_index[ith_channel]['target_idx'],min(batch_npoints[0],len(time_dict_index[ith_channel]['target_idx'])))
                #print('sampled_t_idx ')
                #print(sampled_t_idx )
                sampled_c_idx.sort() 
                sampled_t_idx.sort() 
                ith_context_x,ith_context_y = dataset_dict[ith_channel]['x'][sampled_c_idx],dataset_dict[ith_channel]['y'][sampled_c_idx]
                
                #print('ith_context_x,ith_context_y')
                #print(ith_context_x,ith_context_y)
                
                
                ith_target_x,ith_target_y = dataset_dict[ith_channel]['x'][sampled_t_idx],dataset_dict[ith_channel]['y'][sampled_t_idx]        

                #print('ith_target_x,ith_target_y ')
                #print(ith_target_x,ith_target_y )

            i_context_x.append(ith_context_x)
            i_context_y.append(ith_context_y) 
            i_target_x.append(ith_target_x)
            i_target_y.append(ith_target_y) 
            i_full_x.append(dataset_dict[ith_channel]['x'])
            i_full_y.append(dataset_dict[ith_channel]['y']) 



        i_context_x,i_context_y = np.asarray(i_context_x).T,np.asarray(i_context_y).T
        i_target_x,i_target_y = np.asarray(i_target_x).T,np.asarray(i_target_y).T   
        i_full_x,i_full_y = np.asarray(i_full_x).T,np.asarray(i_full_y).T   

        #print(i_full_x.shape)
        
        #print(i_context_x.shape,i_context_y.shape,i_target_x.shape,i_target_y.shape)
        
        context_x.append( i_context_x )
        context_y.append( i_context_y )
        target_x.append( i_target_x  )
        target_y.append( i_target_y )
        #full_x.append(i_full_x)
        #full_y.append(i_full_y)
    
    #print(type(context_x))        

    context_x = np.asarray(context_x,dtype=np.float32)
    context_y = np.asarray(context_y,dtype=np.float32)
    target_x = np.asarray(target_x,dtype=np.float32)
    target_y = np.asarray(target_y,dtype=np.float32)
    #full_x = np.asarray(full_x,dtype=np.float32)
    #full_y = np.asarray(full_y,dtype=np.float32)
    
    #context_x = torch.tensor(context_x).float()
    #context_y = torch.tensor(context_y).float()
    #target_x = torch.tensor(target_x).float()
    #target_y = torch.tensor(target_y).float()
    
    #return context_x,context_y,target_x,target_y,full_x,full_y
    return context_x,context_y,target_x,target_y

# %%
#---------------------------------------------
# reparation dataset: airpollution "small datset"
#---------------------------------------------
#time_dict_index = get_index(dataset_dict,test_type = 'inter',test_len=24)
time_dict_index = get_index(dataset_dict,test_type = 'extra',test_len=24)



#---------------------------------------------
# reparation dataset: bramblemet "large datset"
#---------------------------------------------
#time_dict_index = get_index(dataset_dict,test_type = 'inter',test_len=128)
#time_dict_index = get_index(dataset_dict,test_type = 'extra',test_len=128)

# %%
context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, time_dict_index , nbatch = 3,batch_npoints=(20,100), intrain = True)


plt.figure(figsize=(20,1.5*num_channels))
for ith in range(num_channels):
    plt.subplot(num_channels,1,ith+1)
    plt.scatter(context_x[2][:,ith],context_y[2][:,ith],color='r',marker='d')
    plt.plot(context_x[2][:,ith],context_y[2][:,ith],'r')
    
    plt.scatter(target_x[2][:,ith],target_y[2][:,ith],color='b',marker='d')
    plt.plot(target_x[2][:,ith],target_y[2][:,ith],'b')    
    
    plt.plot(dataset_dict[ith]['x'],dataset_dict[ith]['y'],'k')
    
plt.show()
print('-'*100)
print('-'*100)
print('-'*100)
    
    
    
context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, time_dict_index , nbatch = 3,batch_npoints=(50,50), intrain = False)
plt.figure(figsize=(20,1.5*num_channels))
for ith in range(num_channels):
    plt.subplot(num_channels,1,ith+1)
    plt.scatter(context_x[2][:,ith],context_y[2][:,ith],color='r',marker='d')
    plt.plot(context_x[2][:,ith],context_y[2][:,ith],'r')
    
    plt.scatter(target_x[2][:,ith],target_y[2][:,ith],color='b',marker='d')
    plt.plot(target_x[2][:,ith],target_y[2][:,ith],'b')    
    
    plt.plot(dataset_dict[ith]['x'],dataset_dict[ith]['y'],'k')
plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
## used num dataset

# %%
len(dataset_dict[0]['x']),len(dataset_dict[1]['x']),len(dataset_dict[2]['x']),len(dataset_dict[3]['x'])
# Out:
# (212, 183, 222, 212)

# %%
# #context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, nbatch = 32,batch_npoints=(64,64), test_option = 'inter',target_range = 'in_train',test_len=24)
# #context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, nbatch = 32,batch_npoints=(64,64), test_option = 'inter',target_range = 'out_train',test_len=24)

# #context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, nbatch = 32,batch_npoints=(64,64), test_option = 'extra',target_range = 'in_train',test_len=24)

# #time_dict_index = get_index(dataset_dict,test_type = 'inter',test_len=24)
# #time_dict_index = get_index(dataset_dict,test_type = 'extra',test_len=24)
# time_dict_index = get_index(dataset_dict,test_type = 'extra',test_len=12*12)

# context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, time_dict_index , nbatch = 32,batch_npoints=(128,128), intrain = True)

# plt.figure(figsize=(20,1.5*num_channels))
# for ith in range(num_channels):
#     plt.subplot(num_channels,1,ith+1)
#     plt.plot(context_x[2][:,ith],context_y[2][:,ith],'r.')
#     plt.plot(context_x[2][:,ith],context_y[2][:,ith],'r')
    
#     plt.plot(target_x[2][:,ith],target_y[2][:,ith],'b.')
#     plt.plot(target_x[2][:,ith],target_y[2][:,ith],'b')    
    

    
# context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, time_dict_index , nbatch = 32,batch_npoints=(64,64), intrain = False)

# plt.figure(figsize=(20,1.5*num_channels))
# for ith in range(num_channels):
#     plt.subplot(num_channels,1,ith+1)
#     plt.plot(context_x[2][:,ith],context_y[2][:,ith],'r.')
#     plt.plot(context_x[2][:,ith],context_y[2][:,ith],'r')
    
#     plt.plot(target_x[2][:,ith],target_y[2][:,ith],'b.')
#     plt.plot(target_x[2][:,ith],target_y[2][:,ith],'b')

# %%
## make instance of model

# %%
from model_baseline import ConvCNP_Multi
# from model_proposed import ConvCNP_Multicross
from convcnp.architectures import SimpleConv, UNet

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
#import stheno.torch as stheno

import convcnp.data
from convcnp.experiment import report_loss, RunningAverage
from convcnp.utils import gaussian_logpdf, init_sequential_weights, to_multiple
from convcnp.cnp_multi import RegressionANP, RegressionCNP



device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


def to_numpy(x):
    """Convert a PyTorch tensor to NumPy."""
    return x.squeeze().detach().cpu().numpy()



nbasis = 2
nchannels = 5
iscuda = True
#lr = 1e-3
lr = 5e-4

weight_decay = 1e-4
points_per_unit = 64
in_channels = nchannels
def build_model(model_type):
    if model_type == 'convcnp':
#         model = ConvCNP_Multi(in_channels=in_channels,
#                               rho = UNet(in_channels**2),
#                               points_per_unit=points_per_unit,
#                               rbf_init_l= 0.1,
#                               nbasis = nbasis)
        model = ConvCNP_Multi(in_channels=in_channels,
                              rho = UNet(in_channels**2),
                              points_per_unit=points_per_unit,
                              rbf_init_l= 0.05,
                              nbasis = nbasis)
        
    elif model_type == 'propose':
        #model = ConvCNP_Multicross(in_channels=in_channels,points_per_unit=points_per_unit)
#         model = ConvCNP_Multicross(in_channels=in_channels,
#                                    rho = UNet(in_channels**2),
#                                    points_per_unit=points_per_unit,
#                                    nbasis = nbasis)
        
        model = G_ConvCNP_Multi(in_channels=in_channels,
                              rho = UNet(in_channels**2),
                              points_per_unit=points_per_unit,
                              rbf_init_l= 0.05,
                              nbasis = nbasis)
    elif model_type == 'propose_v3':

        model = Cross_ConvCNP(in_channels=in_channels,
                              rho = UNet(in_channels),
                              points_per_unit=points_per_unit,
                              rbf_init_l= 0.05,
                              nbasis = nbasis)
        
    elif model_type == 'anp':
        model = RegressionANP(input_dim=nchannels,
                              latent_dim=128,
                              num_channels=nchannels)        
        
        

    elif model_type == 'cnp':
        model = RegressionCNP(input_dim=nchannels,
                              latent_dim=128,
                              num_channels=nchannels)
    else:
        pass
    

    if iscuda:
        model = model.cuda()
    opt = torch.optim.Adam(model.parameters(), lr=lr,weight_decay=weight_decay)
    
    
    return model,opt

# %%
# Out:
# 169354

# %%
model
# Out:
# RegressionANP(
#   (encoder): StandardEncoder(
#     (pre_pooling_fn): Sequential(
#       (0): BatchLinear(in_features=10, out_features=128, bias=True)
#       (1): ReLU()
#       (2): BatchLinear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): BatchLinear(in_features=128, out_features=128, bias=True)
#     )
#     (pooling_fn): CrossAttention(
#       (_attention): MultiHeadAttention(
#         (key_transform): BatchLinear(in_features=128, out_features=128, bias=False)
#         (query_transform): BatchLinear(in_features=128, out_features=128, bias=False)
#         (value_transform): BatchLinear(in_features=128, out_features=128, bias=False)
#         (attention): DotProdAttention()
#         (head_combine): BatchLinear(in_features=128, out_features=128, bias=True)
#       )
#       (embedding): BatchMLP(
#         (net): Sequential(
#           (0): Linear(in_features=5, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (ln1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (ff): BatchLinear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (decoder): StandardDecoder(
#     (post_pooling_fn): Sequential(
#       (0): BatchLinear(in_features=133, out_features=128, bias=True)
#       (1): ReLU()
#       (2): BatchLinear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): BatchLinear(in_features=128, out_features=10, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## prepare dataset

# %%
#time_dict_index

# %% [markdown]
# ## train model

# %%
def nparray2tensor(context_x,context_y,target_x,target_y):
    return torch.tensor(context_x).float(),\
           torch.tensor(context_y).float(),\
           torch.tensor(target_x).float(),\
           torch.tensor(target_y).float()



def train_epochs(dataset_dict,time_dict_index,model,opt,ntask=128,nbatch=32,ncontext=32,ntarget=2*32,trainloss='uniform'):
    model.train()
    losses = []
    for _ in range(ntask):
        
        
#         context_x,context_y,target_x,target_y,full_x,full_y = gen_cls.prepare_task(nbatch=nbatch,
#                                                                                    ncontext=ncontext,
#                                                                                    ntarget=ntarget,
#                                                                                    train_range=gen_cls.train_range,
#                                                                                    test_range=gen_cls.test_range,
#                                                                                    noise_true=True,
#                                                                                    intrain = True)


        context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, 
                                                              time_dict_index , 
                                                              nbatch = 4,
                                                              batch_npoints=(ncontext ,ntarget), 
                                                              intrain = True)
    
        context_x,context_y,target_x,target_y = nparray2tensor(context_x,context_y,target_x,target_y)


        y_mean,y_std = model(context_x.cuda(),context_y.cuda(),target_x.cuda())
    
    
        if trainloss == 'uniform':
            loss = []
            obj = -gaussian_logpdf(target_y.cuda(), y_mean, y_std, 'batched_mean')        
        elif trainloss == 'weight':
            loss = []
            for j in range(in_channels):
                loss.append(-gaussian_logpdf(target_y[:,:,j].cuda(), y_mean[:,:,j], y_std[:,:,j], 'batched_mean').unsqueeze(dim=0) )
            loss = torch.cat(loss)
            weights = y_std.mean(dim=(0,1)).detach().clone()
            #print(loss,weights)
            obj = (loss*weights ).mean()
        else :
            pass

        
        # Optimization
        obj.backward()
        opt.step()
        opt.zero_grad()
        
        #losses.append(obj.item())
        losses.append(obj.cpu().data.numpy())        
        
    avg_loss = np.array(losses).mean()
    return avg_loss,loss




def validate_epochs(dataset_dict,time_dict_index,model,ntask=128,nbatch=32,ncontext=32,ntarget=2*32,train_range= None,test_range=None,intrain=True):
    # large is better 
    model.eval()
    likelihoods = []
    for _ in range(ntask):        
        
#         context_x,context_y,target_x,target_y,full_x,full_y = gen_cls.prepare_task(nbatch=nbatch,
#                                                                                    ncontext=ncontext,
#                                                                                    ntarget=ntarget,
#                                                                                    train_range=gen_cls.train_range,
#                                                                                    test_range=gen_cls.test_range,
#                                                                                    noise_true= True,
#                                                                                    intrain = intrain)

        context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, 
                                                              time_dict_index , 
                                                              nbatch = 4,
                                                              batch_npoints=(ncontext ,ntarget), 
                                                              intrain = intrain)
    
        context_x,context_y,target_x,target_y = nparray2tensor(context_x,context_y,target_x,target_y)


        y_mean,y_std = model(context_x.cuda(),context_y.cuda(),target_x.cuda())
        obj = gaussian_logpdf(target_y.cuda(), y_mean, y_std, 'batched_mean')        
        likelihoods.append(obj.cpu().data.numpy())        
        
    avg_ll,std_ll = np.array(likelihoods).mean().round(2),(np.array(likelihoods).std()/np.sqrt(ntask)).round(2)
    return avg_ll,std_ll        
        
    #avg_ll = np.array(likelihoods).mean()
    #return avg_ll

# %% [markdown]
# ## train model

# %%
#-------------------------------------------
# train
#------------------------------------------
nepochs=2000
ntask,nbatch,ncontext,ntarget = 1,4,20,100
ntask_v,nbatch_v,ncontext_v,ntarget_v = 5,4,20,100
saved_modelparam_path = './param_airquality/{}.pth'.format(model_type)


#-------------------------------------------
# build the model
#------------------------------------------
model_type = 'convcnp'
#model_type = 'anp'

#model_type = 'propose_v3'




model,opt = build_model(model_type=model_type)
model.num_params




#-------------------------
# Task
#-------------------------
tasktype='inter'

#ncontext,ntarget = 20,100
#time_dict_index = get_index(dataset_dict,test_type = 'inter',test_len=48) #split context,target index region
#time_dict_index = get_index(dataset_dict,test_type = 'extra',test_len=58) #split context,target index region
time_dict_index = get_index(dataset_dict,test_type = tasktype,test_len=58) #split context,target index region
 
    
    
best_loss = -np.inf
for i in range(nepochs + 1):   
    #ncontext,ntarget = np.random.randint(10,50,2)    
    
    #avg_loss,loss_list = train_epochs(gen_cls,model,opt,ntask=64,nbatch=32,ncontext=ncontext,ntarget=ntarget,trainloss='weight')    
    #avg_loss,loss_list = train_epochs(gen_cls,model,opt,ntask=64,nbatch=32,ncontext=ncontext,ntarget=ntarget,trainloss=trainloss)    
    #avg_loss,loss_list = train_epochs(dataset_dict,time_dict_index,model,opt,ntask=ntask,nbatch=nbatch,ncontext=ncontext,ntarget=ntarget,trainloss='uniform')
    avg_loss,loss_list = train_epochs(dataset_dict,time_dict_index,model,opt,ntask=ntask,nbatch=nbatch,ncontext=ncontext,ntarget=ntarget,trainloss='weight')
    
    ncontext,ntarget = np.random.randint(10,50,2)        
    #val_loss,_ = validate_epochs(gen_cls,model,ntask=16,nbatch=16,ncontext=ncontext,ntarget=50,intrain=True)
    val_loss,_ = validate_epochs(dataset_dict,time_dict_index,model,ntask=ntask,nbatch=nbatch,ncontext=ncontext,ntarget=ntarget)
    
    
    if best_loss < val_loss:
        best_loss = val_loss        
        saved_dict = {'epoch': i + 1,
                     'best_acc_top1': best_loss,                         
                     'state_dict': model.state_dict(),
                     'optimizer': opt.state_dict()}
        torch.save(saved_dict,saved_modelparam_path)
        print('epochs [{}/{}] | param_saved at {}'.format(i,nepochs,saved_modelparam_path ))

    if i%100 ==0:
        print('epochs [{}/{}] | train loss {:.3f}, val loss {:.3f}'.format(i,nepochs,avg_loss,val_loss) )       
        print(loss_list)    
    torch.cuda.empty_cache()

print('done')
# Out:
# epochs [0/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [0/2000] | train loss 53.090, val loss -82.720
# tensor([ 55.0414,  64.9842, 287.4773,  55.8969,  32.4488], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [4/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [17/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [26/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [66/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [89/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [100/2000] | train loss 35.557, val loss -45.440
# tensor([42.7266, 49.9469, 40.6345, 49.2287, 43.4368], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [106/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [167/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [170/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [200/2000] | train loss 26.931, val loss -34.240
# tensor([39.8122, 34.2347, 34.3493, 47.9982, 37.8488], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [241/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [275/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [300/2000] | train loss 8.175, val loss -22.980
# tensor([15.6890, 12.9179, 11.4620, 15.7366, 13.4215], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [320/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [326/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [351/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [367/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [391/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [399/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [400/2000] | train loss 3.920, val loss -11.530
# tensor([ 8.2660,  5.7411, 23.1144,  2.9462,  6.5756], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [412/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [413/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [424/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [438/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [458/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [465/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [467/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [468/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [473/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [474/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [478/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [479/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [500/2000] | train loss 1.462, val loss -3.290
# tensor([13.9241,  0.9373, -2.7526, -5.4403,  0.5404], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [509/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [519/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [583/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [594/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [595/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [600/2000] | train loss 0.082, val loss 4.550
# tensor([ 21.9072,  -2.0942, -27.2957, -17.7788, -15.2793], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [646/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [700/2000] | train loss 0.720, val loss 1.100
# tensor([ 9.9490, -0.3728, -0.9811, -7.5132, -3.4291], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [751/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [753/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [754/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [757/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [800/2000] | train loss -0.266, val loss 5.100
# tensor([ 10.8017,  -3.7290,   2.9620, -28.5236, -18.6556], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [807/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [810/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [838/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [850/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [873/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [879/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [885/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [900/2000] | train loss -1.017, val loss 14.510
# tensor([  1.6033,  -6.9459, -12.9062,  -6.6049,  -6.6610], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [925/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1000/2000] | train loss -3.229, val loss 22.370
# tensor([-14.3480, -21.4242, -36.9280, -26.3742, -19.3544], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1025/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1030/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1049/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1058/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1072/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1100/2000] | train loss -3.894, val loss 33.970
# tensor([-28.1606, -19.3373, -43.4393, -43.3843, -29.6113], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1200/2000] | train loss -1.963, val loss 18.680
# tensor([-10.7697, -10.3560, -18.2071, -12.5442,  -8.3528], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1258/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1265/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1273/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1300/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1300/2000] | train loss -5.865, val loss 54.270
# tensor([-52.5550, -43.8040, -42.1513, -65.5117, -44.7774], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1311/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1400/2000] | train loss -5.356, val loss 14.330
# tensor([-27.9598, -24.5447, -26.0818, -25.4601, -19.5958], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1500/2000] | train loss -4.133, val loss 37.540
# tensor([-32.9973, -33.2229, -50.4935, -42.5921, -27.2847], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1600/2000] | train loss -2.018, val loss 23.430
# tensor([ -8.6440, -13.1339, -16.9678, -19.7744, -13.2600], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1698/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1700/2000] | train loss -5.674, val loss 32.310
# tensor([-60.4124, -54.9117, -66.6504, -71.6261, -49.0509], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1715/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1728/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [1800/2000] | train loss -4.207, val loss 15.160
# tensor([-26.7536, -21.2767, -30.3845, -31.2242, -23.2471], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1900/2000] | train loss -1.565, val loss 9.880
# tensor([ -6.0137,  -9.6331, -19.4769, -14.2641, -13.4934], device='cuda:0',
#        grad_fn=<CatBackward>)
# epochs [1947/2000] | param_saved at ./param_airquality/convcnp.pth
# epochs [2000/2000] | train loss -5.191, val loss 36.680
# tensor([-49.4394, -21.4505, -56.3618, -48.1912, -36.2214], device='cuda:0',
#        grad_fn=<CatBackward>)
# done

# %% [markdown]
# ## evaluate metric

# %%
path1 = saved_modelparam_path 
model,_ = build_model(model_type=model_type)
load_dict = torch.load(path1)
model.load_state_dict(load_dict['state_dict'])
# Out:
# <All keys matched successfully>

# %%
#ntask = 256
ntask,nbatch,ncontext,ntarget = 256,4,20,100

val_loss_m,val_loss_s = validate_epochs(dataset_dict,time_dict_index,model,ntask=ntask,nbatch=nbatch,ncontext=ncontext,ntarget=ntarget, intrain=False)

model_type,val_loss_m,val_loss_s
# Out:
# ('convcnp', -308.72, 4.05)

# %%
saved_model_path = './fig/exp2_air/'

# %%
datatype = 'airqualtiy'

# %%
ylim_
# Out:
# [-4, 4]

# %%
#ylim_ = [-2.5,2.5]
ylim_ = [-4,4]


#----------------------------------
# small datset
#----------------------------------
context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, time_dict_index , nbatch = 1,batch_npoints=(20,48), intrain = False)
context_x,context_y,target_x,target_y = nparray2tensor(context_x,context_y,target_x,target_y)

#----------------------------------
# large datset
#----------------------------------
# context_x,context_y,target_x,target_y = prepare_batch(dataset_dict, time_dict_index , nbatch = 1,batch_npoints=(500,100), intrain = False)
# context_x,context_y,target_x,target_y = array2tensor(context_x,context_y,target_x,target_y)

#model_m.eval()
#y_mean, y_std = model(context_x,context_y,target_x)
model.eval()
y_mean, y_std = model(context_x.cuda(),context_y.cuda(),target_x.cuda())

#y_mean, y_std = predict_cross(context_x,context_y,target_x,target_y)
y_mean = y_mean.squeeze().cpu().data.numpy()
y_std = y_std.squeeze().cpu().data.numpy()



context_x = context_x.squeeze().cpu().data.numpy()
context_y = context_y.squeeze().cpu().data.numpy()
target_x = target_x.squeeze().cpu().data.numpy()
target_y = target_y.squeeze().cpu().data.numpy()



#xlim_ = [0,220]

#bidx=4
wspace_ = 0.5
hspace_ = 0.25
fontsiz_ = 18
fig = plt.figure(figsize=(9,1.3*5))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace= wspace_, hspace= hspace_)

for j in range(nchannels):
    #plt.subplot(nchannels//2,2,j+1)
    plt.subplot(nchannels,1,j+1)
    
    #imputation region
    #xb = target_x[:,j].min()+0.1,target_x[:,j].max()+0.1
    s_idx,e_idx = time_dict_index[j]['target_idx'][0],time_dict_index[j]['target_idx'][-1]
    xb = dataset_dict[j]['x'][s_idx], dataset_dict[j]['x'][e_idx]
    plt.axvspan(xmin = xb[0],xmax = xb[1], ymin = ylim_[0], ymax = ylim_[1],color='gray', alpha=0.4)

    #dataset
    plt.scatter(context_x[:,j],context_y[:,j],color = 'b',label = 'context',s=50)
    plt.scatter(target_x[:,j],target_y[:,j],color = 'r',label = 'target',s=50)

    plt.plot(dataset_dict[j]['x'],dataset_dict[j]['y'],'k',label='true',linewidth=2.5)
    

    plt.plot(target_x[:,j],y_mean[:,j],color='tab:blue',linewidth=3.0,label='model')
    plt.fill_between(target_x[:,j],
                     y_mean[:,j] + 2 * y_std[:,j],
                     y_mean[:,j] - 2 * y_std[:,j],
                     color='tab:blue', alpha=0.4)
    
    if j == nchannels:
        plt.xticks(np.linspace(0,3.,6),np.linspace(0,3.,6))
    else:
        plt.xticks([])

    plt.ylim(ylim_)
    plt.ylabel('{} ch'.format(j+1),fontsize=fontsiz_)
    #plt.xlim(xlim_)
    plt.yticks(fontsize=fontsiz_-2)

    if j == 0:
        leg = plt.legend(loc = 'upper left',bbox_to_anchor=(.05,1.70),fontsize=fontsiz_,ncol=4,handlelength= 1.5, columnspacing =1.5)
        #leg= plt.legend(bbox_to_anchor=(.52,1.37),fontsize = fontsiz-1, ncol = 6 ,handlelength= 1.5, columnspacing =1.5,) 

        for ii in leg.legendHandles:
            ii.set_linewidth(2)      


fig.tight_layout()    
plt.savefig(saved_model_path +datatype + '_task'.format(tasktype) + '_imputation'+'_{}'.format(model_type)+ '.pdf' , format='pdf', dpi=1000, bbox_inches='tight')
plt.show()
saved_model_path  + datatype + '_task'.format(tasktype)  + '_imputation'+'_{}'.format(model_type)  + '.pdf'
# Out:
# './fig/exp2_air/airqualtiy_task_imputation_convcnp.pdf'

# %%
#dataset_dict[0]['y']-dataset_dict[3]['y']

# %% [markdown]
# ## evaluate metric

# %%
#context_x,context_y,target_x,target_y = prepare_batch(x,(y1,y2,y3),nbatch = 8,batch_npoints=128  ,trainoption= False)        

#test_range = [10,16]

# %%
# Instantiate data generator for testing.
NUM_TEST_TASKS = 2048
#gen_test = convcnp.data.GPGenerator(kernel=kernel, num_tasks=NUM_TEST_TASKS)

# Compute average task log-likelihood.
ravg = RunningAverage()
model.eval()
with torch.no_grad():
#     for step, task in enumerate(gen_test):
#         y_mean, y_std = model(task['x_context'], task['y_context'], task['x_target'])
#         obj = -gaussian_logpdf(task['y_target'], y_mean, y_std, 'batched_mean')
#         ravg.update(obj.item() / gen_test.batch_size, gen_test.batch_size)

    for i in range(10 + 1):   
        #context_x,context_y,target_x,target_y = prepare_batch(x,(y1,y2,y3),nbatch = 16,batch_npoints=batch_npoints ,trainoption= True)        
        context_x,context_y,target_x,target_y = prepare_batch(sin_3channels,
                                                              nbatch = nb,batch_npoints=(64*2,128*2), 
                                                              train_period = train_range, 
                                                              test_period = test_range,
                                                              nchannels=nchannel)

        y_mean,y_std = model(context_x.cuda(),context_y.cuda(),target_x.cuda())
        
        batch_size = context_x.size(0)
        obj = -gaussian_logpdf(target_y.cuda(), y_mean, y_std, 'batched_mean')
        ravg.update(obj.item() / batch_size, batch_size)
        
        
print('Model averages a log likelihood of %.2f on unseen tasks.' % -ravg.avg)

# %%
#Model averages a log likelihood of -47.28 on unseen tasks.
